# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

# %%
df_2017 = pd.read_csv('/Users/rakesh/Documents/DSC167/hmda_2017_nationwide_all-records_labels.csv', 
                      dtype = {'msamd': str, 'state_code': str, 'county_code': str, 'census_tract_number': str,
                              'denial_reason_1':str, 'denial_reason_2': str, 'denial_reason_3': str})
# Out:
# /Users/rakesh/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (34,36,38,44,46,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Rakesh Senthilvelan and Shin Ehara

# %% [markdown]
# ## Introduction
#
# Through our observation of the Housing Mortgage Disclosure Act in relation to fairness based on racial group in 2017, we noticed significant discrepancies when it came to the access to mortgages between Black applicants and White applicants across all income groups. In order to better understand the discrepancies and inequities in mortgage lending, we wanted to look into the areas of inframarginality and threshold testing, as well as intersectionality analysis, when it comes to algorithmic decision making in this area. Through this, we believe that a more fair and equitable classification model can be developed to determine the most likely scenario of someone getting their loan application originated or not.

# %% [markdown]
# ## Data Preparation
#
# For the case of our classification system, we wanted to compare between whether or not a loan was approved or denied. To do this, we had to prepare our data as there are numerous data points that have end results such as "loan was withdrawn", "file closed for incompleteness", or "loan was purchased by financial institution" among others. To handle this, we merged the values for "loan originated" and "application approved but not accepted" into one value, "application denied by financial institutio" into another, and then dropped the remaining columns. We will use this subset of the data as the source for our classification model.

# %%
df_copy = df_2017.copy()

# %%
df_copy['action_taken'] = df_copy['action_taken'].replace(2,1)

# %%
no_drop = [1,3]
df = df_copy[df_copy.action_taken.isin(no_drop)]
# df.action_taken.value_counts()

# %%
df.columns
# Fairness: ['property_type', 'loan_type', 'loan_purpose', 'owner_occupancy', 'loan_amount_000s', 
# 'applicant_income_000s', 'number_of_owner_occupied_units', 'number_of_1_to_4_family_units']
# Out:
# Index(['as_of_year', 'respondent_id', 'agency_name', 'agency_abbr',
#        'agency_code', 'loan_type_name', 'loan_type', 'property_type_name',
#        'property_type', 'loan_purpose_name', 'loan_purpose',
#        'owner_occupancy_name', 'owner_occupancy', 'loan_amount_000s',
#        'preapproval_name', 'preapproval', 'action_taken_name', 'action_taken',
#        'msamd_name', 'msamd', 'state_name', 'state_abbr', 'state_code',
#        'county_name', 'county_code', 'census_tract_number',
#        'applicant_ethnicity_name', 'applicant_ethnicity',
#        'co_applicant_ethnicity_name', 'co_applicant_ethnicity',
#        'applicant_race_name_1', 'applicant_race_1', 'applicant_race_name_2',
#        'applicant_race_2', 'applicant_race_name_3', 'applicant_race_3',
#        'applicant_race_name_4', 'applicant_race_4', 'applicant_race_name_5',
#        'applicant_race_5', 'co_applicant_race_name_1', 'co_applicant_race_1',
#        'co_applicant_race_name_2', 'co_applicant_race_2',
#        'co_applicant_race_name_3', 'co_applicant_race_3',
#        'co_applicant_race_name_4', 'co_applicant_race_4',
#        'co_applicant_race_name_5', 'co_applicant_race_5', 'applicant_sex_name',
#        'applicant_sex', 'co_applicant_sex_name', 'co_applicant_sex',
#        'applicant_income_000s', 'purchaser_type_name', 'purchaser_type',
#        'denial_reason_name_1', 'denial_reason_1', 'denial_reason_name_2',
#        'denial_reason_2', 'denial_reason_name_3', 'denial_reason_3',
#        'rate_spread', 'hoepa_status_name', 'hoepa_status', 'lien_status_name',
#        'lien_status', 'edit_status_name', 'edit_status', 'sequence_number',
#        'population', 'minority_population', 'hud_median_family_income',
#        'tract_to_msamd_income', 'number_of_owner_occupied_units',
#        'number_of_1_to_4_family_units', 'application_date_indicator',
#        'loan_to_income'],
#       dtype='object')

# %%
df['loan_to_income'] = df['loan_amount_000s']/df['applicant_income_000s']
# Out:
# /Users/rakesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# In order to train our model in a fair way, we wanted to look into which intersectional group of race and gender saw the highest level of loan acceptance in this dataset. To do this, we did preliminary data analysis comparisons between gender, then we look into the mixture of that gender and race to determine which group sees the highest acceptance rates. Our hypothesis is that this group will be represented by white males. Also, due to the nature of the dataset, the analysis of gender data only include the binary of male and female.

# %%
df_race_action = df[['action_taken_name','action_taken','applicant_race_name_1','applicant_race_1', 'applicant_sex']]
male_action = df_race_action[df_race_action['applicant_sex'] == 1]
male_demo = male_action['action_taken'].value_counts(normalize=True) * 100
# male_demo

# %%
df_race_action = df[['action_taken_name','action_taken','applicant_race_name_1','applicant_race_1', 'applicant_sex']]
female_action = df_race_action[df_race_action['applicant_sex'] == 2]
female_demo = female_action['action_taken'].value_counts(normalize=True) * 100
# female_demo

# %%
race = ['Male','Female']
reject = [19.005611, 22.710742]

plt.bar(race, reject)
plt.title('Percentage of Loan Application Rejection by Gender')
plt.xlabel('Gender')
plt.ylabel('Percentage of Rejected Applications')
plt.show()

# %% [markdown]
# Through the above graph, we can see that males face lower rates of loan rejection and higher rates of loan acceptance than females do. To further analyze, we will look into the intersection of race and gender to see which group has the lowest rejection rate.

# %%
white_male_action = df_race_action[(df_race_action['applicant_sex'] == 1) & (df_race_action['applicant_race_1'] == 5)]
white_male_demo = white_male_action['action_taken'].value_counts(normalize=True) * 100
white_male_demo
# Out:
# 1    82.546645
# 3    17.453355
# Name: action_taken, dtype: float64

# %%
black_male_action = df_race_action[(df_race_action['applicant_sex'] == 1) & (df_race_action['applicant_race_1'] == 3)]
black_male_demo = black_male_action['action_taken'].value_counts(normalize=True) * 100
black_male_demo
# Out:
# 1    67.767625
# 3    32.232375
# Name: action_taken, dtype: float64

# %%
race = ['White Male','Black Male']
reject = [17.453355, 32.232375]

plt.bar(race, reject)
plt.title('Percentage of Loan Application Rejection by Race and Gender')
plt.xlabel('Race and Gender')
plt.ylabel('Percentage of Rejected Applications')
plt.show()

# %% [markdown]
# Based on the above graph, we can see that White males have a lower rate of rejection than Black males. From this analysis, we will develop our training set off of this demographic.

# %% [markdown]
# ## Building the Model
#
# Now, we will build our model that takes fairness into account. First, we will build the model using training data derived from White males. We believe that due to this intersectional group holding the lowest rejection rate in the dataset in the scope of our research, this will present the most fair subset of the data to pull from as we do not have training data that we can call inherently fair to build the model upon. In terms of the variables used, we will remove sensitive variables including race, ethnicity, sex, minority population percentage in an area, and geographic location to eliminate any biases. We will train the model using the variables of property type, loan type, loan purpose, owner occupancy, our engineered feature for loan to income ratio, and number of owner occupied units. We will develop this model using a Random Forest Classifier.
#
# The reason why we picked these traits is based on correlation as well as the nature of the problem at hand. We created a correlation matrix for all the variables in this dataset and found significant correlations between property type, loan purposes, and purcharser type in relation to action taken with coefficients of 0.1322, 0.1544, and 0.3888 respectively. In addition, we trained on applicant income, loan amount, and loan to income ratio as well due to the financial nature of this situation as such factors would naturally be taken into consideration in any loan-based situation.

# %%
w_m_df =  df[(df['applicant_sex'] == 1) & (df['applicant_race_1'] == 5)]
w_m_df = w_m_df[['property_type', 'loan_type', 'loan_purpose', 'owner_occupancy', 'loan_amount_000s','applicant_income_000s',
                 'loan_to_income', 
                 'number_of_owner_occupied_units', 'action_taken','purchaser_type']]
w_m_df = w_m_df.astype({'action_taken': 'str', 'property_type':'str','loan_type':'str', 'loan_purpose':'str', 
                        'owner_occupancy':'str','purchaser_type':'str'})
w_m_df = w_m_df.dropna()

# %%
w_m_df.dtypes
# Out:
# property_type                      object
# loan_type                          object
# loan_purpose                       object
# owner_occupancy                    object
# loan_amount_000s                  float64
# applicant_income_000s             float64
# loan_to_income                    float64
# number_of_owner_occupied_units    float64
# action_taken                       object
# purchaser_type                     object
# dtype: object

# %%
clf = RandomForestClassifier(max_depth=10)
X = w_m_df[['loan_type', 'loan_purpose', 'loan_to_income', 'loan_amount_000s','applicant_income_000s','purchaser_type']]
y = w_m_df['action_taken']
clf.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
df_no_na = df.copy()
df_no_na = df_no_na[(df_no_na['applicant_race_1'] == 3) | (df_no_na['applicant_race_1'] == 5)]
df_no_na = df_no_na[['applicant_race_1','applicant_sex','applicant_income_000s','loan_amount_000s','property_type', 'loan_type', 'loan_purpose', 'owner_occupancy', 'loan_to_income', 
                 'number_of_owner_occupied_units', 'action_taken', 'purchaser_type']]
df_no_na = df_no_na.astype({'action_taken': 'str', 'property_type':'str','loan_type':'str', 'loan_purpose':'str', 
                        'owner_occupancy':'str','purchaser_type':'str'})
df_no_na = df_no_na.dropna()

# print(clf.predict(df_no_na[['property_type', 'loan_type', 'loan_purpose', 'owner_occupancy', 
#                             'loan_to_income', 'number_of_owner_occupied_units']]))
# df_no_na.head()
# Out:
#     applicant_race_1  applicant_sex  applicant_income_000s  loan_amount_000s  \
# 1                  5              1                   60.0             168.0
# 3                  5              2                   53.0              88.0
# 9                  5              2                   31.0              94.0
# 10                 3              2                   26.0              95.0
# 11                 5              1                   36.0              38.0
#
#    property_type loan_type loan_purpose owner_occupancy  loan_to_income  \
# 1              1         1            3               1        2.800000
# 3              1         1            3               2        1.660377
# 9              1         1            3               2        3.032258
# 10             1         2            3               1        3.653846
# 11             1         1            1               2        1.055556
#
#     number_of_owner_occupied_units action_taken purchaser_type
# 1                            861.0            3              0
# 3                            573.0            1              3
# 9                           1019.0            1              0
# 10                          2517.0            3              0
# 11                          2450.0            3              0

# %%
a = clf.predict(df_no_na[['loan_type', 'loan_purpose', 'loan_to_income', 'loan_amount_000s',
                          'applicant_income_000s','purchaser_type']])

# print(a)
# Out:
# ['3' '1' '3' ... '3' '1' '1']

# %%
# from collections import Counter

# d = Counter(a)
# d
# Out:
# Counter({'3': 942001, '1': 6466359})

# %%
# df_no_na.action_taken.value_counts()
# Out:
# 1    5979301
# 3    1429059
# Name: action_taken, dtype: int64

# %%
# 5979301 /(5979301 + 1429059)
# Out:
# 0.807101841703157

# %%
# 6466359 / (7369719 + 38641)
# Out:
# 0.8728462169764968

# %%
df.corr()
# Out:
#                                 as_of_year  agency_code  loan_type  \
# as_of_year                             NaN          NaN        NaN
# agency_code                            NaN     1.000000   0.036319
# loan_type                              NaN     0.036319   1.000000
# property_type                          NaN    -0.041578  -0.065528
# loan_purpose                           NaN     0.084329  -0.065511
# owner_occupancy                        NaN    -0.068010  -0.169073
# loan_amount_000s                       NaN     0.015522  -0.010770
# preapproval                            NaN     0.004056  -0.102986
# action_taken                           NaN     0.098279  -0.009801
# applicant_ethnicity                    NaN    -0.068370  -0.059329
# co_applicant_ethnicity                 NaN     0.021543   0.021908
# applicant_race_1                       NaN    -0.076411  -0.024554
# applicant_race_2                       NaN    -0.180633   0.053757
# applicant_race_3                       NaN    -0.177212   0.121760
# applicant_race_4                       NaN    -0.191179   0.081414
# applicant_race_5                       NaN    -0.270487   0.124240
# co_applicant_race_1                    NaN     0.010311   0.023893
# co_applicant_race_2                    NaN    -0.158376   0.042234
# co_applicant_race_3                    NaN    -0.164944   0.118940
# co_applicant_race_4                    NaN    -0.183349   0.091413
# co_applicant_race_5                    NaN    -0.308311   0.104069
# applicant_sex                          NaN    -0.035625  -0.085791
# co_applicant_sex                       NaN     0.022912   0.032056
# applicant_income_000s                  NaN     0.004111  -0.026020
# purchaser_type                         NaN    -0.093514   0.188241
# rate_spread                            NaN    -0.080422  -0.361611
# hoepa_status                           NaN     0.006333   0.004178
# lien_status                            NaN     0.020578  -0.142210
# edit_status_name                       NaN          NaN        NaN
# edit_status                            NaN          NaN        NaN
# sequence_number                        NaN          NaN        NaN
# population                             NaN     0.028828   0.042257
# minority_population                    NaN     0.121705   0.013418
# hud_median_family_income               NaN     0.062484  -0.094489
# tract_to_msamd_income                  NaN     0.047174  -0.090389
# number_of_owner_occupied_units         NaN    -0.003060   0.036677
# number_of_1_to_4_family_units          NaN    -0.015068   0.060239
# application_date_indicator             NaN          NaN        NaN
# loan_to_income                         NaN     0.000783   0.001627
#
#                                 property_type  loan_purpose  owner_occupancy  \
# as_of_year                                NaN           NaN              NaN
# agency_code                         -0.041578      0.084329        -0.068010
# loan_type                           -0.065528     -0.065511        -0.169073
# property_type                        1.000000     -0.082090         0.166910
# loan_purpose                        -0.082090      1.000000        -0.012291
# owner_occupancy                      0.166910     -0.012291         1.000000
# loan_amount_000s                     0.080551     -0.004703         0.064720
# preapproval                          0.047942      0.427368         0.040720
# action_taken                         0.132283      0.154475        -0.023138
# applicant_ethnicity                  0.126012      0.042079         0.205924
# co_applicant_ethnicity               0.039920     -0.002451         0.026215
# applicant_race_1                     0.067361      0.044160         0.090243
# applicant_race_2                     0.019471     -0.079246        -0.026672
# applicant_race_3                     0.019440     -0.095679        -0.024100
# applicant_race_4                     0.037823     -0.063159        -0.037786
# applicant_race_5                    -0.004005     -0.069297        -0.073339
# co_applicant_race_1                  0.034645      0.003268         0.018518
# co_applicant_race_2                  0.025038     -0.065875        -0.013112
# co_applicant_race_3                  0.049080     -0.094974        -0.041737
# co_applicant_race_4                  0.040681     -0.304858         0.030813
# co_applicant_race_5                  0.040413     -0.088361        -0.003153
# applicant_sex                        0.113805      0.034051         0.168992
# co_applicant_sex                     0.032549      0.000221         0.025065
# applicant_income_000s               -0.015904      0.004862         0.031762
# purchaser_type                      -0.116337     -0.222568        -0.082306
# rate_spread                          0.520159      0.027262         0.011034
# hoepa_status                        -0.015756      0.002180        -0.000114
# lien_status                         -0.002402      0.040772        -0.031153
# edit_status_name                          NaN           NaN              NaN
# edit_status                               NaN           NaN              NaN
# sequence_number                           NaN           NaN              NaN
# population                          -0.030728     -0.024404        -0.056932
# minority_population                 -0.010669      0.043269         0.043603
# hud_median_family_income            -0.090146      0.040944        -0.027892
# tract_to_msamd_income               -0.084726     -0.003248        -0.067713
# number_of_owner_occupied_units      -0.032735     -0.031418        -0.088858
# number_of_1_to_4_family_units       -0.003871     -0.035869        -0.020751
# application_date_indicator                NaN           NaN              NaN
# loan_to_income                      -0.000979     -0.000547        -0.001745
#
#                                 loan_amount_000s  preapproval  action_taken  \
# as_of_year                                   NaN          NaN           NaN
# agency_code                             0.015522     0.004056      0.098279
# loan_type                              -0.010770    -0.102986     -0.009801
# property_type                           0.080551     0.047942      0.132283
# loan_purpose                           -0.004703     0.427368      0.154475
# owner_occupancy                         0.064720     0.040720     -0.023138
# loan_amount_000s                        1.000000     0.000026     -0.017124
# preapproval                             0.000026     1.000000      0.114047
# action_taken                           -0.017124     0.114047      1.000000
# applicant_ethnicity                     0.052129     0.041647     -0.002397
# co_applicant_ethnicity                 -0.007334    -0.004906      0.075037
# applicant_race_1                        0.021128     0.025010     -0.034624
# applicant_race_2                        0.009494    -0.089135     -0.081894
# applicant_race_3                       -0.021440    -0.101439     -0.032438
# applicant_race_4                       -0.033354    -0.078855     -0.004618
# applicant_race_5                       -0.027653    -0.060823     -0.048513
# co_applicant_race_1                    -0.010209    -0.004532      0.065513
# co_applicant_race_2                    -0.041486    -0.063528     -0.050022
# co_applicant_race_3                     0.039630    -0.064396     -0.028612
# co_applicant_race_4                    -0.119879    -0.298279     -0.041913
# co_applicant_race_5                    -0.037773    -0.070060     -0.121840
# applicant_sex                           0.038251     0.037517      0.039138
# co_applicant_sex                       -0.007050    -0.003882      0.072081
# applicant_income_000s                   0.518316     0.003900     -0.014709
# purchaser_type                         -0.002419    -0.153647     -0.388888
# rate_spread                            -0.094856     0.183899           NaN
# hoepa_status                            0.001143     0.006045      0.009699
# lien_status                            -0.037965     0.110796      0.144555
# edit_status_name                             NaN          NaN           NaN
# edit_status                                  NaN          NaN           NaN
# sequence_number                              NaN          NaN           NaN
# population                              0.000240    -0.023161     -0.021527
# minority_population                     0.010084     0.018730      0.078611
# hud_median_family_income                0.046151     0.008913     -0.058063
# tract_to_msamd_income                   0.049876    -0.003443     -0.077220
# number_of_owner_occupied_units         -0.006819    -0.026191     -0.036930
# number_of_1_to_4_family_units          -0.014856    -0.022391     -0.014781
# application_date_indicator                   NaN          NaN           NaN
# loan_to_income                          0.527540    -0.000062      0.002781
#
#                                 applicant_ethnicity  ...  edit_status  \
# as_of_year                                      NaN  ...          NaN
# agency_code                               -0.068370  ...          NaN
# loan_type                                 -0.059329  ...          NaN
# property_type                              0.126012  ...          NaN
# loan_purpose                               0.042079  ...          NaN
# owner_occupancy                            0.205924  ...          NaN
# loan_amount_000s                           0.052129  ...          NaN
# preapproval                                0.041647  ...          NaN
# action_taken                              -0.002397  ...          NaN
# applicant_ethnicity                        1.000000  ...          NaN
# co_applicant_ethnicity                     0.120437  ...          NaN
# applicant_race_1                           0.305336  ...          NaN
# applicant_race_2                          -0.013936  ...          NaN
# applicant_race_3                           0.025119  ...          NaN
# applicant_race_4                          -0.009094  ...          NaN
# applicant_race_5                           0.080611  ...          NaN
# co_applicant_race_1                        0.070875  ...          NaN
# co_applicant_race_2                       -0.017546  ...          NaN
# co_applicant_race_3                       -0.081190  ...          NaN
# co_applicant_race_4                       -0.127982  ...          NaN
# co_applicant_race_5                        0.055855  ...          NaN
# applicant_sex                              0.528863  ...          NaN
# co_applicant_sex                           0.064403  ...          NaN
# applicant_income_000s                      0.010437  ...          NaN
# purchaser_type                            -0.093233  ...          NaN
# rate_spread                                0.115920  ...          NaN
# hoepa_status                               0.002432  ...          NaN
# lien_status                               -0.022075  ...          NaN
# edit_status_name                                NaN  ...          NaN
# edit_status                                     NaN  ...          NaN
# sequence_number                                 NaN  ...          NaN
# population                                -0.045061  ...          NaN
# minority_population                       -0.157640  ...          NaN
# hud_median_family_income                   0.063695  ...          NaN
# tract_to_msamd_income                      0.040091  ...          NaN
# number_of_owner_occupied_units            -0.001976  ...          NaN
# number_of_1_to_4_family_units             -0.007374  ...          NaN
# application_date_indicator                      NaN  ...          NaN
# loan_to_income                             0.001184  ...          NaN
#
#                                 sequence_number  population  \
# as_of_year                                  NaN         NaN
# agency_code                                 NaN    0.028828
# loan_type                                   NaN    0.042257
# property_type                               NaN   -0.030728
# loan_purpose                                NaN   -0.024404
# owner_occupancy                             NaN   -0.056932
# loan_amount_000s                            NaN    0.000240
# preapproval                                 NaN   -0.023161
# action_taken                                NaN   -0.021527
# applicant_ethnicity                         NaN   -0.045061
# co_applicant_ethnicity                      NaN   -0.022673
# applicant_race_1                            NaN   -0.045233
# applicant_race_2                            NaN   -0.005814
# applicant_race_3                            NaN   -0.013040
# applicant_race_4                            NaN   -0.099597
# applicant_race_5                            NaN   -0.133965
# co_applicant_race_1                         NaN   -0.026414
# co_applicant_race_2                         NaN   -0.015980
# co_applicant_race_3                         NaN    0.009783
# co_applicant_race_4                         NaN   -0.069568
# co_applicant_race_5                         NaN   -0.148815
# applicant_sex                               NaN   -0.023375
# co_applicant_sex                            NaN   -0.016776
# applicant_income_000s                       NaN   -0.001307
# purchaser_type                              NaN    0.043320
# rate_spread                                 NaN   -0.027611
# hoepa_status                                NaN    0.003680
# lien_status                                 NaN   -0.019329
# edit_status_name                            NaN         NaN
# edit_status                                 NaN         NaN
# sequence_number                             NaN         NaN
# population                                  NaN    1.000000
# minority_population                         NaN    0.107348
# hud_median_family_income                    NaN   -0.008682
# tract_to_msamd_income                       NaN    0.126736
# number_of_owner_occupied_units              NaN    0.880137
# number_of_1_to_4_family_units               NaN    0.845888
# application_date_indicator                  NaN         NaN
# loan_to_income                              NaN    0.000365
#
#                                 minority_population  hud_median_family_income  \
# as_of_year                                      NaN                       NaN
# agency_code                                0.121705                  0.062484
# loan_type                                  0.013418                 -0.094489
# property_type                             -0.010669                 -0.090146
# loan_purpose                               0.043269                  0.040944
# owner_occupancy                            0.043603                 -0.027892
# loan_amount_000s                           0.010084                  0.046151
# preapproval                                0.018730                  0.008913
# action_taken                               0.078611                 -0.058063
# applicant_ethnicity                       -0.157640                  0.063695
# co_applicant_ethnicity                     0.076408                 -0.024229
# applicant_race_1                          -0.212435                 -0.077421
# applicant_race_2                          -0.114385                 -0.039156
# applicant_race_3                           0.045155                  0.029217
# applicant_race_4                           0.047686                  0.065243
# applicant_race_5                           0.056878                 -0.025228
# co_applicant_race_1                        0.048652                 -0.052918
# co_applicant_race_2                       -0.087406                 -0.052590
# co_applicant_race_3                        0.081659                  0.010572
# co_applicant_race_4                       -0.040042                 -0.016405
# co_applicant_race_5                        0.140649                 -0.058326
# applicant_sex                              0.056686                  0.020128
# co_applicant_sex                           0.098048                 -0.032747
# applicant_income_000s                     -0.007032                  0.028308
# purchaser_type                            -0.010559                  0.038318
# rate_spread                               -0.072653                 -0.065296
# hoepa_status                               0.000139                  0.007697
# lien_status                                0.028594                 -0.047133
# edit_status_name                                NaN                       NaN
# edit_status                                     NaN                       NaN
# sequence_number                                 NaN                       NaN
# population                                 0.107348                 -0.008682
# minority_population                        1.000000                  0.039821
# hud_median_family_income                   0.039821                  1.000000
# tract_to_msamd_income                     -0.295913                 -0.020160
# number_of_owner_occupied_units            -0.180853                 -0.018505
# number_of_1_to_4_family_units             -0.130007                 -0.137702
# application_date_indicator                      NaN                       NaN
# loan_to_income                             0.002574                  0.001945
#
#                                 tract_to_msamd_income  \
# as_of_year                                        NaN
# agency_code                                  0.047174
# loan_type                                   -0.090389
# property_type                               -0.084726
# loan_purpose                                -0.003248
# owner_occupancy                             -0.067713
# loan_amount_000s                             0.049876
# preapproval                                 -0.003443
# action_taken                                -0.077220
# applicant_ethnicity                          0.040091
# co_applicant_ethnicity                      -0.091882
# applicant_race_1                             0.018379
# applicant_race_2                             0.012763
# applicant_race_3                            -0.045986
# applicant_race_4                            -0.081880
# applicant_race_5                            -0.027740
# co_applicant_race_1                         -0.093049
# co_applicant_race_2                         -0.006470
# co_applicant_race_3                         -0.000179
# co_applicant_race_4                         -0.118077
# co_applicant_race_5                         -0.068679
# applicant_sex                               -0.050074
# co_applicant_sex                            -0.093553
# applicant_income_000s                        0.050621
# purchaser_type                               0.000618
# rate_spread                                  0.008831
# hoepa_status                                 0.004749
# lien_status                                 -0.047136
# edit_status_name                                  NaN
# edit_status                                       NaN
# sequence_number                                   NaN
# population                                   0.126736
# minority_population                         -0.295913
# hud_median_family_income                    -0.020160
# tract_to_msamd_income                        1.000000
# number_of_owner_occupied_units               0.278706
# number_of_1_to_4_family_units                0.116151
# application_date_indicator                        NaN
# loan_to_income                               0.000299
#
#                                 number_of_owner_occupied_units  \
# as_of_year                                                 NaN
# agency_code                                          -0.003060
# loan_type                                             0.036677
# property_type                                        -0.032735
# loan_purpose                                         -0.031418
# owner_occupancy                                      -0.088858
# loan_amount_000s                                     -0.006819
# preapproval                                          -0.026191
# action_taken                                         -0.036930
# applicant_ethnicity                                  -0.001976
# co_applicant_ethnicity                               -0.046522
# applicant_race_1                                     -0.000355
# applicant_race_2                                      0.014837
# applicant_race_3                                     -0.022401
# applicant_race_4                                     -0.112143
# applicant_race_5                                     -0.161917
# co_applicant_race_1                                  -0.044356
# co_applicant_race_2                                   0.005291
# co_applicant_race_3                                   0.014701
# co_applicant_race_4                                  -0.094933
# co_applicant_race_5                                  -0.169991
# applicant_sex                                        -0.043140
# co_applicant_sex                                     -0.047230
# applicant_income_000s                                 0.001062
# purchaser_type                                        0.039033
# rate_spread                                           0.007817
# hoepa_status                                          0.002791
# lien_status                                          -0.017054
# edit_status_name                                           NaN
# edit_status                                                NaN
# sequence_number                                            NaN
# population                                            0.880137
# minority_population                                  -0.180853
# hud_median_family_income                             -0.018505
# tract_to_msamd_income                                 0.278706
# number_of_owner_occupied_units                        1.000000
# number_of_1_to_4_family_units                         0.908520
# application_date_indicator                                 NaN
# loan_to_income                                       -0.000450
#
#                                 number_of_1_to_4_family_units  \
# as_of_year                                                NaN
# agency_code                                         -0.015068
# loan_type                                            0.060239
# property_type                                       -0.003871
# loan_purpose                                        -0.035869
# owner_occupancy                                     -0.020751
# loan_amount_000s                                    -0.014856
# preapproval                                         -0.022391
# action_taken                                        -0.014781
# applicant_ethnicity                                 -0.007374
# co_applicant_ethnicity                              -0.034626
# applicant_race_1                                     0.011579
# applicant_race_2                                     0.017864
# applicant_race_3                                    -0.020433
# applicant_race_4                                    -0.113698
# applicant_race_5                                    -0.152178
# co_applicant_race_1                                 -0.028318
# co_applicant_race_2                                  0.004926
# co_applicant_race_3                                  0.003853
# co_applicant_race_4                                 -0.072212
# co_applicant_race_5                                 -0.152034
# applicant_sex                                       -0.035483
# co_applicant_sex                                    -0.034034
# applicant_income_000s                               -0.004213
# purchaser_type                                       0.025700
# rate_spread                                          0.011178
# hoepa_status                                         0.001446
# lien_status                                         -0.010967
# edit_status_name                                          NaN
# edit_status                                               NaN
# sequence_number                                           NaN
# population                                           0.845888
# minority_population                                 -0.130007
# hud_median_family_income                            -0.137702
# tract_to_msamd_income                                0.116151
# number_of_owner_occupied_units                       0.908520
# number_of_1_to_4_family_units                        1.000000
# application_date_indicator                                NaN
# loan_to_income                                      -0.000570
#
#                                 application_date_indicator  loan_to_income
# as_of_year                                             NaN             NaN
# agency_code                                            NaN        0.000783
# loan_type                                              NaN        0.001627
# property_type                                          NaN       -0.000979
# loan_purpose                                           NaN       -0.000547
# owner_occupancy                                        NaN       -0.001745
# loan_amount_000s                                       NaN        0.527540
# preapproval                                            NaN       -0.000062
# action_taken                                           NaN        0.002781
# applicant_ethnicity                                    NaN        0.001184
# co_applicant_ethnicity                                 NaN        0.001975
# applicant_race_1                                       NaN        0.000417
# applicant_race_2                                       NaN        0.016119
# applicant_race_3                                       NaN        0.028523
# applicant_race_4                                       NaN        0.022560
# applicant_race_5                                       NaN        0.047715
# co_applicant_race_1                                    NaN        0.001771
# co_applicant_race_2                                    NaN        0.003475
# co_applicant_race_3                                    NaN        0.063949
# co_applicant_race_4                                    NaN       -0.062434
# co_applicant_race_5                                    NaN        0.039843
# applicant_sex                                          NaN        0.001940
# co_applicant_sex                                       NaN        0.002085
# applicant_income_000s                                  NaN       -0.001248
# purchaser_type                                         NaN        0.000203
# rate_spread                                            NaN       -0.160211
# hoepa_status                                           NaN        0.000125
# lien_status                                            NaN       -0.004291
# edit_status_name                                       NaN             NaN
# edit_status                                            NaN             NaN
# sequence_number                                        NaN             NaN
# population                                             NaN        0.000365
# minority_population                                    NaN        0.002574
# hud_median_family_income                               NaN        0.001945
# tract_to_msamd_income                                  NaN        0.000299
# number_of_owner_occupied_units                         NaN       -0.000450
# number_of_1_to_4_family_units                          NaN       -0.000570
# application_date_indicator                             NaN             NaN
# loan_to_income                                         NaN        1.000000
#
# [39 rows x 39 columns]

# %% [markdown]
# Our model, using Random Forest Classifier and the selected variables, approved 87.28% of the applicants compared to the 80.71% that were approved in our original sample. We believe that developing this training model using the fairness metrics brought up earlier were beneficial in creating a more equal lending system. Now, we will look into the fairness of this algorithm through the lenses of Individual Fairness and Intersectionality.

# %% [markdown]
# ## Intersectionality Analysis
#
# One of the main characteristics we noticed in our data was that Black applicants were rejected a signficantly higher rate than White applicants, as seen earlier in the section titled "Data Preparation" as well as our first paper. When looking into the intersectionality between race and income in our first paper, we noticed that Black applicants in the dataset were consistently rejected at a higher rate than White applicants. That is represented by the following graph, brought from our first paper.

# %%
x_values = ['$0-10k', '$10-40k','$40-85k','$85-163k','$163k-207k','$207k-518k','$518k+']
y1_values = [55.494530, 26.015737, 14.133654, 10.164868,9.027158,9.058271,10.293484]
y2_values = [70.951658, 39.880038, 23.696660, 18.517326,16.957265,16.980620,23.787062]

df = pd.DataFrame(list(zip(x_values, y1_values, y2_values)),columns = ['Income Bracket', 
                                                                       'White Rejection Rate','Black Rejection Rate'])

plt.plot('Income Bracket', 'White Rejection Rate', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot('Income Bracket', 'Black Rejection Rate', data=df, marker='o', markerfacecolor='red', markersize = 12, color='pink', linewidth=4)

plt.legend()
plt.title('Rejection Rates by Income Bracket and Race')
plt.show()

# %% [markdown]
# For this intersectionality analysis, we will once again look into the areas of race and income, but we will also look into the area of sex as well as we were able to find a difference in rejection rates based on sex. For the case of our analysis, we will first look at the rejection rates on these different identities in the original data set and then compare those statistics on the predictions of our model.
